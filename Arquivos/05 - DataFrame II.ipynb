# %%
import pandas as pd

# %%
employees = pd.read_csv("employees.csv")

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
employees["Start Date"] = pd.to_datetime(employees["Start Date"], format = "%m/%d/%Y")

# %%
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format = "%H:%M %p").dt.time

# %%
employees["Senior Management"] = employees["Senior Management"].astype(bool)

# %%
employees["Gender"] = employees["Gender"].astype("category")

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 49.1+ KB

# %%
employees = pd.read_csv("employees.csv", parse_dates = ["Start Date"], date_format = "%m/%d/%Y")

# %%
employees[employees["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06        12:42 PM   97308    6.945
# 1       Thomas   Male 1996-03-31         6:53 AM   61933    4.170
# 3        Jerry   Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry   Male 1998-01-24         4:47 PM  101004    1.389
# 5       Dennis   Male 1987-04-18         1:35 AM  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male 2013-06-21         5:47 PM   98874    4.479
# 996    Phillip   Male 1984-01-31         6:30 AM   42392   19.675
# 997    Russell   Male 2013-05-20        12:39 PM   96914    1.421
# 998      Larry   Male 2013-04-20         4:45 PM   60500   11.985
# 999     Albert   Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
employees[employees["Team"] == "Finance"]
on_finance_team = employees["Team"] == "Finance"
employees[on_finance_team]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 7          NaN  Female 2015-07-20        10:43 AM   45906   11.598
# 14    Kimberly  Female 1999-01-14         7:13 AM   41426   14.543
# 46       Bruce    Male 2009-11-28        10:47 PM  114796    6.796
# ..         ...     ...        ...             ...     ...      ...
# 907  Elizabeth  Female 1998-07-27        11:12 AM  137144   10.081
# 954        Joe    Male 1980-01-19         4:06 PM  119667    1.148
# 987     Gloria  Female 2014-12-08         5:08 AM  136709   10.331
# 992    Anthony    Male 2011-10-16         8:35 AM  112769   11.625
# 996    Phillip    Male 1984-01-31         6:30 AM   42392   19.675
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                 NaN  Finance
# 14               True  Finance
# ...

# %%
employees[employees["Senior Management"] == True]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1       Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 3        Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry    Male 1998-01-24         4:47 PM  101004    1.389
# 6         Ruby  Female 1987-08-17         4:20 PM   65476   10.012
# ..         ...     ...        ...             ...     ...      ...
# 991       Rose  Female 2002-08-25         5:12 AM  134505   11.051
# 992    Anthony    Male 2011-10-16         8:35 AM  112769   11.625
# 993       Tina  Female 1997-05-15         3:53 PM   56450   19.040
# 994     George    Male 2013-06-21         5:47 PM   98874    4.479
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management             Team
# 0                True        Marketing
# 1                True              NaN
# 3                True          Finance
# ...

# %%
import datetime as dt

# %%
employees[employees["Salary"] > 110000]
employees[employees["Bonus %"] < 1.5]
employees[employees["Start Date"] < "1985-01-01"]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12         9:01 AM   63241   15.132
# 12     Brandon    Male 1980-12-01         1:08 AM  112807   17.492
# 18       Diana  Female 1981-10-23        10:27 AM  132940   19.082
# 28       Terry    Male 1981-11-27         6:30 PM  124008   13.464
# 37       Linda  Female 1981-10-19         8:49 PM   57427    9.557
# ..         ...     ...        ...             ...     ...      ...
# 982       Rose  Female 1982-04-06        10:43 AM   91411    8.639
# 983       John    Male 1982-12-23        10:35 PM  146907   11.738
# 985    Stephen     NaN 1983-07-10         8:10 PM   85668    1.909
# 986      Donna  Female 1982-11-26         7:04 AM   82871   17.999
# 996    Phillip    Male 1984-01-31         6:30 AM   42392   19.675
#
#     Senior Management             Team
# 10               True              NaN
# 12               True  Human Resources
# 18              False  Client Services
# ...

# %%
employees[employees["Last Login Time"] < str(dt.time(12, 0, 0))]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 7          NaN  Female 2015-07-20        10:43 AM   45906   11.598
# 13        Gary    Male 2008-01-27        11:40 PM  109831    5.831
# 18       Diana  Female 1981-10-23        10:27 AM  132940   19.082
# 24        John    Male 1992-07-01        10:08 PM   97950   13.873
# ..         ...     ...        ...             ...     ...      ...
# 968     Louise  Female 1995-03-27        10:27 PM   43050   11.671
# 973    Russell    Male 2013-05-10        11:08 PM  137359   11.105
# 975      Susan  Female 1995-04-07        10:05 PM   92436   12.467
# 982       Rose  Female 1982-04-06        10:43 AM   91411    8.639
# 983       John    Male 1982-12-23        10:35 PM  146907   11.738
#
#     Senior Management                  Team
# 2               False               Finance
# 7                 NaN               Finance
# ...

# %%
is_female = employees["Gender"] == "Female"
is_in_marketing = employees["Team"] == "Marketing"
salary_over_100k = employees["Salary"] > 100000

# %%
is_female & is_in_marketing & salary_over_100k
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
employees[is_female & is_in_marketing & salary_over_100k]
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 98         Tina  Female 2016-06-16         7:47 PM  100705   16.961
# 140     Shirley  Female 1981-02-28         1:23 PM  113850    1.854
# 158       Norma  Female 1999-02-28         8:45 PM  114412    8.756
# 305    Margaret  Female 1993-02-06         1:05 PM  125220    3.733
# 319  Jacqueline  Female 1981-11-25         3:01 PM  145988   18.243
# 379         NaN  Female 2002-09-18        12:39 PM  118906    4.537
# 468      Janice  Female 1997-06-28         1:48 PM  136032   10.696
# 490      Judith  Female 2007-11-23         1:22 PM  117055    7.461
# 531    Virginia  Female 2010-05-02         9:10 PM  123649   10.154
# 585     Shirley  Female 1988-04-16        11:09 AM  132156    2.754
# 627        Anne  Female 1984-11-21        12:30 PM  128305   16.636
# 656        Lisa  Female 1982-02-09         6:44 PM  113592   17.108
# 675       Diane  Female 2009-10-30         6:56 PM  130577   12.791
# ...

# %%
is_senior_management = employees["Senior Management"]
before_january1st98 = employees["Start Date"] < "1998-01-01"
employees[is_senior_management | before_january1st98]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1       Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2        Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry    Male 1998-01-24         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 992    Anthony    Male 2011-10-16         8:35 AM  112769   11.625
# 993       Tina  Female 1997-05-15         3:53 PM   56450   19.040
# 994     George    Male 2013-06-21         5:47 PM   98874    4.479
# 996    Phillip    Male 1984-01-31         6:30 AM   42392   19.675
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management             Team
# 0                True        Marketing
# 1                True              NaN
# 2               False          Finance
# ...

# %%
name_robert = employees["First Name"] == "Robert"
work_in_client_services = employees["Team"] == "Client Services"
start_after_june1st2016 = employees["Start Date"] > "2016-06-01"
employees[(name_robert & work_in_client_services) | start_after_june1st2016]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05         6:09 AM   59414    1.256
# 98        Tina  Female 2016-06-16         7:47 PM  100705   16.961
# 387     Robert    Male 1994-10-29         4:26 AM  123294   19.894
# 451      Terry     NaN 2016-07-15        12:29 AM  140002   19.490
#
#     Senior Management             Team
# 15              False          Product
# 98               True        Marketing
# 387             False  Client Services
# 451              True        Marketing

# %%
legal_team = employees["Team"] == "Legal"
sales_team = employees["Team"] == "Sales"
product_team = employees["Team"] == "Product"
employees[legal_team | sales_team | product_team]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18         1:35 AM  115163   10.125
# 6         Ruby  Female 1987-08-17         4:20 PM   65476   10.012
# 11       Julie  Female 1997-10-26         3:19 PM  102508   12.637
# 13        Gary    Male 2008-01-27        11:40 PM  109831    5.831
# 15     Lillian  Female 2016-06-05         6:09 AM   59414    1.256
# ..         ...     ...        ...             ...     ...      ...
# 981      James    Male 1993-01-15         5:19 PM  148985   19.280
# 985    Stephen     NaN 1983-07-10         8:10 PM   85668    1.909
# 989     Justin     NaN 1991-02-10         4:58 PM   38344    3.794
# 997    Russell    Male 2013-05-20        12:39 PM   96914    1.421
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# ...

# %%
target_teams = employees["Team"].isin(["Legal", "Sales", "Product"])
employees[target_teams]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18         1:35 AM  115163   10.125
# 6         Ruby  Female 1987-08-17         4:20 PM   65476   10.012
# 11       Julie  Female 1997-10-26         3:19 PM  102508   12.637
# 13        Gary    Male 2008-01-27        11:40 PM  109831    5.831
# 15     Lillian  Female 2016-06-05         6:09 AM   59414    1.256
# ..         ...     ...        ...             ...     ...      ...
# 981      James    Male 1993-01-15         5:19 PM  148985   19.280
# 985    Stephen     NaN 1983-07-10         8:10 PM   85668    1.909
# 989     Justin     NaN 1991-02-10         4:58 PM   38344    3.794
# 997    Russell    Male 2013-05-20        12:39 PM   96914    1.421
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# ...

# %%
employees["Team"].isnull()
employees[employees["Team"].isnull()]
# Out:
#       First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 10        Louise  Female 1980-08-12         9:01 AM   63241   15.132
# 23           NaN    Male 2012-06-14         4:19 PM  125792    5.042
# 32           NaN    Male 1998-08-21         2:27 PM  122340    6.417
# 91         James     NaN 2005-01-26        11:00 PM  128771    8.309
# 109  Christopher    Male 2000-04-22        10:15 AM   37919   11.449
# 139          NaN  Female 1990-10-03         1:08 AM  132373   10.527
# 199     Jonathan    Male 2009-07-17         8:15 AM  130581   16.736
# 258      Michael    Male 2002-01-24         3:04 AM   43586   12.659
# 290       Jeremy    Male 1988-06-14         6:20 PM  129460   13.657
# 314        Bobby    Male 1996-03-31         5:40 PM  112117    6.338
# 367       Edward    Male 1989-08-04         6:06 AM   66067   10.957
# 382          NaN  Female 1996-04-18         3:57 PM  107024   12.182
# ...

# %%
employees["Team"].notnull()
employees[employees["Team"].notnull()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 2        Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry    Male 1998-01-24         4:47 PM  101004    1.389
# 5       Dennis    Male 1987-04-18         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23         6:09 AM  132483   16.655
# 996    Phillip    Male 1984-01-31         6:30 AM   42392   19.675
# 997    Russell    Male 2013-05-20        12:39 PM   96914    1.421
# 998      Larry    Male 2013-04-20         4:45 PM   60500   11.985
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
employees[employees["First Name"].isnull() & employees["Team"].notnull()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 7          NaN  Female 2015-07-20        10:43 AM   45906   11.598
# 25         NaN    Male 2012-10-08         1:12 AM   37076   18.576
# 39         NaN    Male 2016-01-29         2:33 AM  122173    7.797
# 51         NaN     NaN 2011-12-17         8:29 AM   41126   14.009
# 62         NaN  Female 2007-06-12         5:25 PM   58112   19.414
# 116        NaN    Male 1991-06-22         8:58 PM   76189   18.988
# 149        NaN  Female 2014-08-17         2:00 PM   86230    8.578
# 157        NaN  Female 2005-07-27         8:32 AM   79536   14.443
# 165        NaN  Female 2014-03-23         1:28 PM   59148    9.061
# 166        NaN  Female 1991-07-09         6:52 PM   42341    7.014
# 174        NaN     NaN 2007-09-18         6:59 PM   40297    6.185
# 186        NaN  Female 2005-02-23         9:50 PM  149654    1.825
# 220        NaN  Female 1991-06-17        12:49 PM   71945    5.560
# ...

# %%
employees["Salary"].between(60000, 70000)
employees[employees["Salary"].between(60000, 70000)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 6         Ruby  Female 1987-08-17         4:20 PM   65476   10.012
# 10      Louise  Female 1980-08-12         9:01 AM   63241   15.132
# 20        Lois     NaN 1995-04-22         7:18 PM   64714    4.934
# 41   Christine     NaN 2015-06-28         1:08 AM   66582   11.308
# ..         ...     ...        ...             ...     ...      ...
# 965  Catherine  Female 1989-09-25         1:31 AM   68164   18.393
# 970      Alice  Female 1988-09-03         8:54 PM   63571   15.397
# 974      Harry    Male 2011-08-30         6:31 PM   67656   16.455
# 978       Sean    Male 1983-01-17         2:23 PM   66146   11.178
# 998      Larry    Male 2013-04-20         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# ...

# %%
employees["Bonus %"].between(2.0, 5.0)
employees[employees["Bonus %"].between(2.0, 5.0)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 20        Lois     NaN 1995-04-22         7:18 PM   64714    4.934
# 40     Michael    Male 2008-10-10        11:25 AM   99283    2.665
# 49       Chris     NaN 1980-01-24        12:13 PM  113590    3.055
# 60       Paula     NaN 2005-11-23         2:01 PM   48866    4.271
# ..         ...     ...        ...             ...     ...      ...
# 943      Wayne    Male 2006-09-08        11:09 AM   67471    2.728
# 961    Antonio     NaN 1989-06-18         9:37 PM  103050    3.050
# 976     Denise  Female 1992-10-19         5:42 AM  137954    4.195
# 989     Justin     NaN 1991-02-10         4:58 PM   38344    3.794
# 994     George    Male 2013-06-21         5:47 PM   98874    4.479
#
#     Senior Management          Team
# 1                True           NaN
# 20               True         Legal
# 40               True  Distribution
# ...

# %%
employees[employees["Start Date"].between("1991-01-01", "1992-01-01")]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11         6:58 PM  122367    5.218
# 75      Bonnie  Female 1991-07-02         1:27 AM  104897    5.118
# 88       Donna  Female 1991-11-27         1:59 PM   64088    6.155
# 116        NaN    Male 1991-06-22         8:58 PM   76189   18.988
# 148    Patrick     NaN 1991-07-14         2:24 AM  124488   14.837
# 166        NaN  Female 1991-07-09         6:52 PM   42341    7.014
# 172       Sara  Female 1991-09-23         6:17 PM   97058    9.402
# 220        NaN  Female 1991-06-17        12:49 PM   71945    5.560
# 245     Victor    Male 1991-04-11         7:44 AM   70817   17.138
# 277     Brenda     NaN 1991-05-29         6:32 AM   82439   19.062
# 313       Judy  Female 1991-07-01         2:33 AM  109510   13.457
# 328     Samuel    Male 1991-12-19         2:54 AM   76076    5.319
# 339    Michael    Male 1991-11-22        12:57 PM   98753   16.443
# ...

# %%
employees[employees["First Name"].duplicated()]
employees[employees["First Name"].duplicated(keep="first")]
employees[employees["First Name"].duplicated(keep="last")]
employees[employees["First Name"].duplicated(keep=False)]
employees[~employees["First Name"].duplicated(keep=False)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18         1:35 AM  115163   10.125
# 8       Angela  Female 2005-11-22         6:29 AM   95570   18.523
# 33        Jean  Female 1993-12-18         9:07 AM  119082   16.180
# 190      Carol  Female 1996-03-19         3:39 AM   57783    9.129
# 291      Tammy  Female 1984-11-11        10:30 AM  132839   17.463
# 495     Eugene    Male 1984-05-24        10:54 AM   81077    2.117
# 688      Brian    Male 2007-04-07        10:47 PM   93901   17.821
# 832      Keith    Male 2003-02-12         3:02 PM  120672   19.467
# 887      David    Male 2009-12-05         8:48 AM   92242   15.407
#
#     Senior Management                  Team
# 5               False                 Legal
# 8                True           Engineering
# 33              False  Business Development
# 190             False               Finance
# 291              True       Client Services
# ...

# %%
employees.drop_duplicates("Team")
employees.drop_duplicates("Team", keep="first")
employees.drop_duplicates("Team", keep="last")
employees.drop_duplicates("Team", keep=False)

employees.drop_duplicates("First Name", keep=False)
employees.drop_duplicates(["Senior Management", "Team"]).sort_values("Team")
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 481        NaN  Female 2013-04-27         6:40 AM   93847    1.085
# 33        Jean  Female 1993-12-18         9:07 AM  119082   16.180
# 9      Frances  Female 2002-08-08         6:51 AM  139852    7.524
# 25         NaN    Male 2012-10-08         1:12 AM   37076   18.576
# 18       Diana  Female 1981-10-23        10:27 AM  132940   19.082
# 4        Larry    Male 1998-01-24         4:47 PM  101004    1.389
# 40     Michael    Male 2008-10-10        11:25 AM   99283    2.665
# 60       Paula     NaN 2005-11-23         2:01 PM   48866    4.271
# 149        NaN  Female 2014-08-17         2:00 PM   86230    8.578
# 54        Sara  Female 2007-08-15         9:23 AM   83677    8.999
# 8       Angela  Female 2005-11-22         6:29 AM   95570   18.523
# 329        NaN    Male 2010-01-27         2:57 AM   87760   14.987
# 3        Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# ...

# %%
employees["Gender"].unique()
type(employees["Gender"].unique())
employees["Gender"].nunique(dropna=True)
employees["Gender"].nunique(dropna=False)
# Out:
# 3

# %%
employees["Team"].unique()
type(employees["Team"].unique())
employees["Team"].nunique(dropna=True)
employees["Team"].nunique(dropna=False)
# Out:
# 11
